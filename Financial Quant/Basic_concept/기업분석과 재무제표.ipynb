# %% [markdown]
# # 1. 산업의 이해와 기업분석

# %% [markdown]
# ## 산업의 이해 필요성
# * 산업의 이해는 기업분석의 시작점
# * 산업마다 다른 특성들이 존재하기 때문에, 기업을 분석하기 위해서는 기업이 영위하는 산업에 대한 분석이 반드시 선행되어야 함
#
# <img src="https://blog.kakaocdn.net/dn/c4w2mR/btrLgGaJXvh/SPfjLuAjkqT2ERI8FrG2n0/img.png">

# %% [markdown]
# ## 정보수집
# * 상장사의 경우 전자공시시스템(dsrt.fss.or.kr)을 통해 분기별로 사업보고서(분기, 반기보고서) 공시
# * 사업의 내용을 통해 기업이 영위하는 산업에 대하여 정리하여 제출
# * 최초 상장하는 기업의 경우 투자설명서를 통해 더욱 자세한 산업에 대한 정보 제출
#
# <img src="https://blog.kakaocdn.net/dn/c50Mda/btrLfN9CD6c/cz9RZyx7BwVJRqJO9GRpTk/img.png">

# %% [markdown]
# ## 산업분석 : 마이클포터의 5 Forces 모델

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/c3YOWt/btrLgkTzWES/6vDGZ7bz5gNmvDcGuewtS0/img.png">

# %% [markdown]
# ### 신규진입자의 교섭력(Threat of new entrants)
# * 진입장벽을 낮추는 요인(=산업 매력도 하락 요인)
#     - 초기 자본금 규모가 적음
#     - 정부의 진입규제가 적음
#     - 규모의 경제에 쉽게 도달
#     - 제품 차별화가 적음

# %% [markdown]
# ### 공급자 교섭력(Bargaining power of suppliers)
# * 공급자 교섭력을 증가시키는 요인(=산업 매력도 하락 요인)
#     - 공급자의 수가 적음
#     - 공급제품간 차별성 많음
#     - 대체재의 존재 적음
#     - 공급자 변경이 어려움
#     - 공급자의 대형화 가능성 많음

# %% [markdown]
# ### 수요자 교섭력(Bargaining power of buyers)
# * 수요자 교섭력을 증가시키는 요인(= 산업 매력도 하락 요인)
#     - 수요자의 수가 적음
#     - 대체재의 존재 많음
#     - 제품차별화 정도 낮음
#     - 소득에서 차지하는 비중 높음

# %% [markdown]
# ### 대체재의 위협(Threat of substitute products)
# * 대체재 출현 가능성을 높이는 요인(=산업 매력도 하락 요인)
#     - 대체재의 질적 수준이 높음
#     - 대체재의 가격 수준이 낮음
#     - 수요자들의 다른 제품 구매가능성이 높음

# %% [markdown]
# ### 산업 내 경쟁(Threat of rivalry among existing competitors)
# * 경쟁강도를 증가시키는 요인(=산업 매력도 하락 요인)
#     - 경쟁기업의 수가 많음
#     - 시장규모가 작음
#     - 향후 시장성장률이 낮음
#     - 제품간 차별성이 낮음
#     - 고정비용이 적음
#     - 시장에서 철수하기 쉬움

# %% [markdown]
# ## 산업분석 : PEST 분석
# * 거시환경분석으로 정치적(Political)환경, 경제적(Economical)환경, 사회적(Social)환경, 기술적(Technological)환경으로 기업이 처한 환경을 구분하여 분석
#
# <img src="https://blog.kakaocdn.net/dn/mlNKo/btrLec9LEB4/aRafwlBNK7h4ke8OeV2h0k/img.png" width=500px>

# %% [markdown]
# ## 산업분석 : SWOT 분석 모델
# * 기업이 처한 환경 분석을 통해 강점(Strength), 약점(Weakness), 기회(Opportunity), 위협(Threat) 요인을 규정하고 이를 토대로 전략을 수립하는 기법
#
# <img src="https://blog.kakaocdn.net/dn/uRfZt/btrLgS3gt1y/1pJbgESysSKAx7HqSUij0K/img.png" width=500px>

# %% [markdown]
# # 2. 재무제표 분석과 재무지표 분석

# %% [markdown]
# ## 회계(Accounting)란
# * 정보이용자가 합리적인 판단이나 의사결정을 할 수 있도록 경제적 정보를 식별하고 측정하여 전달하는 과정 => 회계는 기업의 언어
#
# ||재무회계|관리회계|세무회계|
# |--|--|--|--|
# |목적|외부보고|내부보고|세무보고
# |정보이용자|투자자, 채권자 등 외부정보이용자|경영자,관리자 등 내부정보이용자|국가, 지방자치단체|
# |작성원칙|한국채택국제회계기준|다양함|세법|
# |보고형태|재무제표|다양함|세무조정계산서|

# %% [markdown]
# ## 재무제표(Financial statements)란
# * 기업실체에 관한 재무적 정보를 외부 정보이용자에게 전달하는 재무보고(Fianacial reporting)의 수단
# * 일정시점의 상태에 관한 재무제표:
#     - 재무상태표(Statement of financial position)
# * 일정기간의 변동에 관한 재무제표:
#     - 손익계산서(Statement of comprehensive income)
#     - 현금흐름표(Statement of cash flow)
#     - 자본변동표(Statement of change in equity)
# * + 재무제표에 대한 주석(Footnote)

# %% [markdown]
# ### 재무상태표 : 일정시점의 기업의 재무상태에 대한 보고서

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/bqnSEp/btrLgrrBgVn/K0G5fkZ5l4LdTNb8BcVMP1/img.png" width=700px>

# %% [markdown]
# ### 손익계산서 : 일정기간 동안의 기업의 경영실적에 대한 보고서
#
# <img src="https://blog.kakaocdn.net/dn/bodRNJ/btrLgPr5dml/1AHrnkYU0krUrsvZNxuZdK/img.png" width=700px>

# %% [markdown]
# * 감가상각비(무형자산상각비)
#     - 유형자산(무형자산)의 경우 해당 자산의 내용연수 동안 추정되는 잔존가치를 제외한 부분에 대하여 비용(감가상각비)으로 인식하여야 함 => 현금의 유출이 없는 비용
# * EBITDA(Earning before interest tax depreciation amortization)
#     - 기업이 영업활동을 벌어들인 현금창출능력을 나타내는 지표
#     - 영업이익 + 감가상각비 + 무형자산상각비

# %% [markdown]
# ### 현금흐름표 : 일정기간 동안의 기업의 현금흐름에 대한 보고서
#
# <img src="https://blog.kakaocdn.net/dn/bLR0su/btrLgSWAitJ/n6aPGMKuohYRhkEisYAqeK/img.png" width=500px>
#
# * 현금주의(현금흐름표)와 발생주의(손익계산서)
#     - 현금주의 : 현금의 유출입을 기준으로 손익 등 인식
#     - 발생주의 : 회계의 기본원칙으로 손익을 발생하는 기간의 손익으로 인식
# * 영업활동으로 인한 현금흐름
#     - 기업의 실질적인 현금흐름창출능력을 보여주므로
#     - => 영업손익과 비교 필요

# %% [markdown]
# ## 자금의 순환과정

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/b3ySr6/btrLuyrwIAi/9ZRlVTZdZKvoxdixviJSYk/img.png">

# %% [markdown]
# * 기업은 채권자와 주주로부터 자금 조달
# * 기업은 영업을 통해 창출한 영업현금흐름을 이자와 원금으로 채권자에게 지급
# * 잔여현금은 주주에게 배당 또는 유보를 통해 영업확대

# %% [markdown]
# ## 연결재무제표vs별도재무제표vs개별재무제표

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/nt4eU/btrLy2x7GoB/EnTWLgEVK4vVaGsCCLX7P0/img.png">

# %% [markdown]
# ## 재무비율 분석

# %% [markdown]
# * 기업의 재무상태(재무상태표)와 경영실적(손익계산서)의 분석을 위해 재무제표 항목의 비율을 산출하여 분석
#     * 산업간 특성이 다르므로, 유사기업 또는 대상기업의 과거 실적과의 적절한 비교를 통하여 사용하여야 함
#     * 재무비율의 산출 이유에 대해 분석하고 향후 전망할 것

# %% [markdown]
# ### 유동성 비율
# * 기업의 단기 지급 능력을 평가하는 지표
# * 유동비율(Current  ratio) = 유동자산 / 유동부채
#     * 높을수록 높은 유동성이 풍부
# * 당좌비율(Quick ratio) = 당좌자산 / 유동부채
#     * 당좌자산 = 유동자산 - 재고자산
#     * 유동자산 중 유동성이 떨어질 수 있는 재고자산을 제외하고 유동성을 측정
#
# <img src="https://blog.kakaocdn.net/dn/zjMGi/btrLxYJy2l0/hKgUpmStbMflnjoRls3WWK/img.png" width=500px>

# %% [markdown]
# ### 안정성 비율
# * 기업의 장기지급능력을 평가하는 지표
# * 부채비율(Debt to equity ratio) = 부채/자본(자기자본)
#     * 낮을수록 안정성이 높음
# * 이자보상비율(Interest coverage ratio) = 영업이익 / 이자비용
#     * 높을수록 안정성이 높음
# * 고정장기적합률 = 비유동자산 / 자기자본 + 비유동부채
#     * 낮을수록 안정성이 높음

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/qWiRF/btrLyYCBJX9/FQ94PjuthTTkEcNyfKOhL0/img.png" width=500px>

# %% [markdown]
# ### 수익성비율
# * 기업의 경영성과를 나타내는 지표
# * 매출총이익률 = 매출총이익 / 매출
#     * 매출총이익 = 매출 - 매출원가
# * 영업이익률 = 영업이익/매출
#     * 영업이익 = 매출총이익 - 판매비와관리비
# * 순이익률 = 순이익 / 매출
# * 총자산순이익률(Return on assets = Return on investment) = 순이익/총자산
# * 자기자본순이익률(Return on equity=ROE) = 순이익 / 자기자본

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/cXvEcA/btrLy2SsrTg/bVf6m4bX9aOgsZuwUnfWu1/img.png" width=500px>
# * 자기자본/총자산은 연초와 연말의 평균으로 계산

# %% [markdown]
# ### 활동성비율
# * 기업의 자산이 효율적으로 운용되는지 나타내는 지표
# * 매출채권회전율 = 매출액/매출채권
#     * 매출채권 평균회수기간 = 365/매출채권회전율
# * 재고자산회전율 = 매출원가/재고자산
#     * 재고자산 평균회전기간 = 365/재고자산회전율
# * 총자산회전율 = 매출액/총자산

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/4rZDN/btrLy2dSVFH/SJeZKgBKYYObZFmZLZBLY1/img.png" width=500px>

# %% [markdown]
# ### 성장성비율
# * 기업의 성장성을 나타내는 지표
# * 매출액증가율 = 당기매출액/전기매출액-1
# * 영업이익증가율 = 당기영업이익/전기영업이익-1
# * 순이익증가율 = 당기순이익/전기순이익-1
# * 총자산증가율 = 당기총자산/전기총자산-1

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/GWGet/btrLzEKqvld/LlqArOCkpyzEQ5Jjw9VPnk/img.png" width=500px>

# %% [markdown]
# ### 시장성비율
# * 기업의 시장가치와의 비율을 나타내는 지표
# * PER(Price earning ratio) = 주가/주당순이익 = 시가총액/당기순이익
# * PBR(Price book value ratio) = 주가/주당순자산 = 시가총액 /순자산
# * PSR(Price Sales ratio) = 주가/주당매출액 = 시가총액/매출

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/rMAiN/btrLy25ZRSE/uMVHSLV0QqRktUnuod0AX1/img.png" width=500px>
