# %%
from konlpy.tag import Okt
okt = Okt()
print(okt.nouns("게시글이 좋았다면 공감을 눌러주세요!!"))
print(okt.pos('아버지가 방에 들어가신다'))
print(okt.pos('아버지가방에들어가신다'))
# Out:
# ['게시', '글', '공감']
# [('아버지', 'Noun'), ('가', 'Josa'), ('방', 'Noun'), ('에', 'Josa'), ('들어가신다', 'Verb')]
# [('아버지', 'Noun'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가신다', 'Verb')]

# %%
from konlpy.tag import Kkma
kkma = Kkma()
print(kkma.nouns("게시글이 좋았다면 공감을 눌러주세요!!"))
print(kkma.pos('아버지가 방에 들어가신다'))
print(kkma.pos('아버지가방에들어가신다'))
# Out:
# ['게시', '게시글', '글', '공감', '주세']
# [('아버지', 'NNG'), ('가', 'JKS'), ('방', 'NNG'), ('에', 'JKM'), ('들어가', 'VV'), ('시', 'EPH'), ('ㄴ다', 'EFN')]
# [('아버지', 'NNG'), ('가방', 'NNG'), ('에', 'JKM'), ('들어가', 'VV'), ('시', 'EPH'), ('ㄴ다', 'EFN')]

# %%
from konlpy.tag import Komoran
komoran = Komoran()
print(komoran.nouns("미칠듯 사랑했던 기억이 추억들이 너를 찾고 있지만"))
print(komoran.nouns("사과는 apple 바나나는 banana"))
print(komoran.nouns("게시글이 좋았다면 공감을 눌러주세요!!"))
print(komoran.morphs('아버지가 방에 들어가신다'))
print(komoran.pos('아버지가 방에 들어가신다'))
print(komoran.pos('아버지가방에들어가신다'))
# Out:
# ['듯', '사랑', '기억', '추억']
# ['사과', '바나나']
# ['게시', '글', '공감']
# ['아버지', '가', '방', '에', '들어가', '시', 'ㄴ다']
# [('아버지', 'NNG'), ('가', 'JKS'), ('방', 'NNG'), ('에', 'JKB'), ('들어가', 'VV'), ('시', 'EP'), ('ㄴ다', 'EC')]
# [('아버지', 'NNG'), ('가방', 'NNP'), ('에', 'JKB'), ('들어가', 'VV'), ('시', 'EP'), ('ㄴ다', 'EC')]

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 토큰화(tokenization)

# %%
#re[a-zA-z].split

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from keras.preprocessing.text import text_to_word_sequence

# %%
#import nltk
#nltk.download('punkt')

# %%
print('단어 토큰화1 :',word_tokenize("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# 단어 토큰화1 : ['Do', "n't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', ',', 'Mr.', 'Jone', "'s", 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop', '.']

# %%
print('keras :',text_to_word_sequence("Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop."))
# Out:
# keras : ["don't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', 'mr', "jone's", 'orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop']

# %% [markdown]
# ## 문장 토큰화
# * 구두점(.)으로 자른다.

# %%
from nltk.tokenize import sent_tokenize

text = "Since I'm actively looking for Ph.D. students, I get the same question a dozen times every year."
print('문장 토큰화1 :',sent_tokenize(text))
# Out:
# 문장 토큰화1 : ["Since I'm actively looking for Ph.D. students, I get the same question a dozen times every year."]

# %%
text = "IP 192.168.56.31 서버에 들어가서 로그 파일 저장해서 aaa@gmail.com로 결과 좀 보내줘. 그 후 점심 먹으러 가자."
print('문장 토큰화1 :',sent_tokenize(text))
# Out:
# 문장 토큰화1 : ['IP 192.168.56.31 서버에 들어가서 로그 파일 저장해서 aaa@gmail.com로 결과 좀 보내줘.', '그 후 점심 먹으러 가자.']

# %% [markdown]
# ## 한국어 전용 띄어쓰기

# %%
#pip install kss
import kss

# %%
text = '딥 러닝 자연어 처리가 재미있기는 합니다. 그런데 문제는 영어보다 한국어로 할 때 너무 어렵습니다. 이제 해보면 알걸요?'
print('한국어 문장 토큰화 :',kss.split_sentences(text))
# Out:
# [Korean Sentence Splitter]: Initializing Pynori...
# 한국어 문장 토큰화 : ['딥 러닝 자연어 처리가 재미있기는 합니다.', '그런데 문제는 영어보다 한국어로 할 때 너무 어렵습니다.', '이제 해보면 알걸요?']

# %%
from konlpy.tag import Mecab
mecab = Mecab(r"C:\\mecab\\mecab-ko-dic")

# %%
res=mecab.pos('아버지가방에들어가신다.')
print(res)
# Out:
# [('아버지', 'NNG'), ('가', 'JKS'), ('방', 'NNG'), ('에', 'JKB'), ('들어가', 'VV'), ('신다', 'EP+EF'), ('.', 'SF')]

# %% [markdown]
# ## 어간 추출(Stemming) and 표제어 추출(Lemmatization)
# * Stemming
# * am → am
# * the going → the go
# * having → hav
#
# * Lemmatization
# * am → be
# * the going → the going
# * having → have
#
# 어간(stem) : 용언(동사, 형용사)을 활용할 때, 원칙적으로 모양이 변하지 않는 부분. 활용에서 어미에 선행하는 부분. 때론 어간의 모양도 바뀔 수 있음(예: 긋다, 긋고, 그어서, 그어라).
#
# 어미(ending): 용언의 어간 뒤에 붙어서 활용하면서 변하는 부분이며, 여러 문법적 기능을 수행

# %% [markdown]
# ## 불용어(Stopword)
# * 자주 등장하지만 분석에 필요 없는 단어 ('어제','참','매우')

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASIA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words_list = stopwords.words('english')
print('불용어 개수:', len(stop_words_list))
print('불용어 목록:',stop_words_list[:10])
# Out:
# 불용어 개수: 179
# 불용어 목록: ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
example = "Family is not an important thing. It's everything."
stop_words = set(stopwords.words('english')) 

word_tokens = word_tokenize(example)

result = []
for word in word_tokens: 
    if word not in stop_words: 
        result.append(word) 

print('불용어 제거 전 :',word_tokens) 
print('불용어 제거 후 :',result)
# Out:
# 불용어 제거 전 : ['Family', 'is', 'not', 'an', 'important', 'thing', '.', 'It', "'s", 'everything', '.']
# 불용어 제거 후 : ['Family', 'important', 'thing', '.', 'It', "'s", 'everything', '.']

# %% [markdown]
# ## 한국어 불용어 제거

# %% [markdown]
# * 불용어 : ./dataset/ko_stopword_dict.txt

# %% [markdown]
# * https://velog.io/@csy9604/NLP-%EC%96%B8%EC%A0%9C%EA%B9%8C%EC%A7%80-%EB%AF%B8%EB%A3%B0%EB%9E%98-%EC%9D%BC%EB%8B%A8-%EB%93%A4%EC%96%B4%EC%99%80-2.-NLP-%EC%A0%84%EC%B2%98%EB%A6%AC-%EC%A0%95%EB%A6%AC

# %%
from konlpy import Okt

# %%
okt = Okt()

example = "고기를 아무렇게나 구우려고 하면 안 돼. 고기라고 다 같은 게 아니거든. 예컨대 삼겹살을 구울 때는 중요한 게 있지."
stop_words = "를 아무렇게나 구 우려 고 안 돼 같은 게 구울 때 는"

stop_words = set(stop_words.split(' '))
word_tokens = okt.morphs(example)

result = [word for word in word_tokens if not word in stop_words]

print('불용어 제거 전 :',word_tokens) 
print('불용어 제거 후 :',result)
# Out:
# 불용어 제거 전 : ['고기', '를', '아무렇게나', '구', '우려', '고', '하면', '안', '돼', '.', '고기', '라고', '다', '같은', '게', '아니거든', '.', '예컨대', '삼겹살', '을', '구울', '때', '는', '중요한', '게', '있지', '.']
# 불용어 제거 후 : ['고기', '하면', '.', '고기', '라고', '다', '아니거든', '.', '예컨대', '삼겹살', '을', '중요한', '있지', '.']

# %%
list = ['게','한','은']
stop_arr=np.array(list).reshape(-1,1)
df2 = pd.DataFrame(stop_arr)
# Out:
#    0
# 0  게
# 1  한
# 2  은

# %%
import re
#from konlpy.tag import Okt
#tokenizer = Okt()
import pandas as pd
import numpy as np

def my_stopword(text,mecab):
    df = pd.read_csv('./dataset/ko_stopword_dict.txt')
    list1 = df['stop'].values.tolist()
    list2 = ['게','한','은','갖','고','있']

    stopwords = list1+list2
   
    txt = re.sub('[^가-힣a-z]', ' ', text)
    #token = tokenizer.morphs(txt)
    res = mecab.morphs(txt)
    res = [t for t in res if t not in stopwords]
        
    return res

text_list = ["증시도 윤석열 당선에 '축포'…급등한 종목들은?",
             "'독야청청' 수소 ETF…나스닥 9% 하락때 나홀로 10% '쑥'",
             'LG엔솔, 코스피200 편입 무조건 호재? "공매도 집중타깃" 우려도']
for text in text_list:
    text_list2=sent_tokenize(text)
    print("=====================",text_list2)
    for text2 in text_list2:
        res= my_stopword(text2,mecab)
        print("품사태깅",res)
        print("단어토큰화",mecab.nouns(text2))
# Out:
# ===================== ["증시도 윤석열 당선에 '축포'…급등한 종목들은?"]
# 품사태깅 ['증시', '도', '윤석열', '당선', '축포', '급등', '종목']
# 단어토큰화 ['증시', '윤석열', '당선', '축포', '급등', '종목']
# ===================== ["'독야청청' 수소 ETF…나스닥 9% 하락때 나홀로 10% '쑥'"]
# 품사태깅 ['독야청청', '수소', '나스닥', '하락', '홀로', '쑥']
# 단어토큰화 ['독야청청', '수소', '나스닥', '하락', '때', '나', '쑥']
# ===================== ['LG엔솔, 코스피200 편입 무조건 호재?', '"공매도 집중타깃" 우려도']
# 품사태깅 ['엔', '솔', '코스피', '편입', '무조건', '호재']
# 단어토큰화 ['솔', '코스피', '편입', '호재']
# 품사태깅 ['공매도', '집중', '타깃', '우려', '도']
# 단어토큰화 ['공매도', '집중', '타깃', '우려']

# %%
train=pd.read_csv('./dataset/train.csv')
train=train['중식메뉴']

# %%
menu
# Out:
# array(['쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜  청포묵무침  요구르트  포기김치 (배추,고추가루:국내산) ',
#        '쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무침  요구르트  배추겉절이 (배추,고추가루:국내산) ',
#        '카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침  견과류조림  요구르트  포기김치 (배추,고추가루:국내산) ',
#        ..., '전주비빔밥*약고추장 계란파국 요거닭 올방개묵무침 파프리카해초무침 포기김치 양상추샐러드*자몽D ',
#        '쌀밥/흑미밥/찰현미밥 전주식콩나물해장국 돈육간장불고기 깐풍연근 연두부*달래양념장 봄동겉절이/양념김 양상추샐러드*오렌지D ',
#        '쌀밥/귀리밥/찰현미밥 들깨미역국 교촌간장치킨 옥수수콘치즈구이 가지고추장무침 포기김치/요구르트 양배추샐러드*사우전D '],
#       dtype=object)

# %%
from konlpy.tag import Hannanum

# %%
hannanum=Hannanum()

# %%
menu=train.values
for food in menu:
    print(food)
    print("단어토큰화",hannanum.nouns(food))
# Out:
# 쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜  청포묵무침  요구르트  포기김치 (배추,고추가루:국내산)
# 단어토큰화 ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '오징어찌개', '쇠불고', '쇠고기', '호주산', '계란찜', '청포묵무침', '요구르트', '포기김치', '배추', '고추가루', '국내산']
# 쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무침  요구르트  배추겉절이 (배추,고추가루:국내산)
# 단어토큰화 ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '김치찌개', '가자미튀김', '모둠소세지구', '마늘쫑무침', '요구르트', '배추겉절이', '배추', '고추가루', '국내산']
# 카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침  견과류조림  요구르트  포기김치 (배추,고추가루:국내산)
# 단어토큰화 ['카레덮밥', '(쌀,현미흑미:국내산)', '팽이장국', '치킨핑거', '닭고기', '국내산', '쫄면야채무침', '견과류조림', '요구르트', '포기김치', '배추', '고추가루', '국내산']
# 쌀밥/잡곡밥 (쌀,현미흑미:국내산) 쇠고기무국  주꾸미볶음  부추전  시금치나물  요구르트  포기김치 (배추,고추가루:국내산)
# 단어토큰화 ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '쇠고기무국', '주꾸미볶음', '부추전', '시금치나물', '요구르트', '포기김치', '배추', '고추가루', '국내산']
# 쌀밥/잡곡밥 (쌀,현미흑미:국내산) 떡국  돈육씨앗강정 (돼지고기:국내산) 우엉잡채  청경채무침  요구르트  포기김치 (배추,고추가루:국내산)
# 단어토큰화 ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '떡국', '돈육씨앗강정', '돼지고기', '국내산', '우엉잡채', '청경채무침', '요구르트', '포기김치', '배추', '고추가루', '국내산']
# ...

# %% [markdown]
# ## 정제(cleaning) & 정규화(normalization)
