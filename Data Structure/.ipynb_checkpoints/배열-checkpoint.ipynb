# %% [markdown]
# ![%E1%84%8B%E1%85%B5%E1%84%85%E1%85%B3%E1%86%B7%20%E1%84%8B%E1%85%A5%E1%86%B9%E1%84%82%E1%85%B3%E1%86%AB%20%E1%84%82%E1%85%A9%E1%84%90%E1%85%B3%E1%84%87%E1%85%AE%E1%86%A8-3.jpg](attachment:%E1%84%8B%E1%85%B5%E1%84%85%E1%85%B3%E1%86%B7%20%E1%84%8B%E1%85%A5%E1%86%B9%E1%84%82%E1%85%B3%E1%86%AB%20%E1%84%82%E1%85%A9%E1%84%90%E1%85%B3%E1%84%87%E1%85%AE%E1%86%A8-3.jpg)

# %% [markdown]
# # 파이썬의 배열
# * 파이썬 리스트 활용

# %%
#1차원 배열 : 리스트 구현
data=[1,2,3,4,5]
print(data)
# Out:
# [1, 2, 3, 4, 5]

# %%
#2차원배열 : 리스트 구현
data=[[1,2,3],[4,5,6],[7,8,9]]
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
print(data[0])
# Out:
# [1, 2, 3]

# %%
print(data[0][0])
print(data[1][0])
# Out:
# 1
# 4
